# %%
import pennylane as qml 
import random
from pennylane import qchem
from pennylane import numpy as np
import matplotlib.pyplot as plt

# %%
class VQA:
    
    def __init__(self, qubits, shots):
        self.qubits = qubits
        self.shots = shots
        self.dev = qml.device("default.qubit", wires=self.qubits, shots=self.shots)
        self.qnode = qml.QNode(self.circuit, self.dev, interface="autograd")

    def run(self, params = None):
        def circuit(q):
            initial(q)
            ansatz(params)
            return [qml.expval(qml.PauliZ(k)) for k in range(self.qubits)]
        return circuit(self.qubits)

class VQSD(VQA):
    
    def __init__(self, qubits, shots):
        super().__init__(qubits, shots)
        
             
    def run(self, params = None):
        if params == None:
            params = []
            for i in range(self.qubits):
                params.append(1/random.randint(1,10))
            
        def initial():
            for i in range(self.qubits):
                    qml.Hadamard(i)
        def ansatz(params):
            for j in range(self.qubits):
                qml.RZ(params[j], wires=j)
        def cost_function():
            return [qml.expval(qml.PauliZ(k)) for k in range(self.qubits)]
        
        super().run(params)

# %%
B = VQSD(3, 100)

# %%
B.qubits
# Out:
# 3

# %%
B.run()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_52/995631584.py in <cell line: 1>()
# ----> 1 B.run()
#
# /tmp/ipykernel_52/2522394719.py in run(self, params)
#      35             return [qml.expval(qml.PauliZ(k)) for k in range(self.qubits)]
#      36
# ---> 37         super().run(params)
#      38
#
# /tmp/ipykernel_52/2522394719.py in run(self, params)
#      12             ansatz(params)
#      13             return [qml.expval(qml.PauliZ(k)) for k in range(self.qubits)]
# ---> 14         return circuit(self.qubits)
#      15
#      16 class VQSD(VQA):
#
# /opt/conda/envs/pennylane/lib/python3.9/site-packages/pennylane/qnode.py in __call__(self, *args, **kwargs)
#     798
#     799         # construct the tape
# --> 800         self.construct(args, kwargs)
#     801
#     802         cache = self.execute_kwargs.get("cache", False)
#
# /opt/conda/envs/pennylane/lib/python3.9/site-packages/pennylane/qnode.py in construct(self, args, kwargs)
#     709         """Call the quantum function with a tape context, ensuring the operations get queued."""
#     710
# --> 711         self._tape = make_qscript(self.func)(*args, **kwargs)
#     712         self._tape._queue_category = "_ops"
#     713         self._qfunc_output = self.tape._qfunc_output
#
# /opt/conda/envs/pennylane/lib/python3.9/site-packages/pennylane/tape/qscript.py in wrapper(*args, **kwargs)
#    1344     def wrapper(*args, **kwargs):
#    1345         with AnnotatedQueue() as q:
# -> 1346             result = fn(*args, **kwargs)
#    1347
#    1348         qscript = QuantumScript.from_queue(q)
#
# /tmp/ipykernel_52/2522394719.py in circuit(q)
#       9         @qml.qnode(dev)
#      10         def circuit(q):
# ---> 11             initial(q)
#      12             ansatz(params)
#      13             return [qml.expval(qml.PauliZ(k)) for k in range(self.qubits)]
#
# /opt/conda/envs/pennylane/lib/python3.9/site-packages/pennylane/qnode.py in __call__(self, *args, **kwargs)
#     798
#     799         # construct the tape
# --> 800         self.construct(args, kwargs)
#     801
#     802         cache = self.execute_kwargs.get("cache", False)
#
# /opt/conda/envs/pennylane/lib/python3.9/site-packages/pennylane/qnode.py in construct(self, args, kwargs)
#     709         """Call the quantum function with a tape context, ensuring the operations get queued."""
#     710
# --> 711         self._tape = make_qscript(self.func)(*args, **kwargs)
#     712         self._tape._queue_category = "_ops"
#     713         self._qfunc_output = self.tape._qfunc_output
#
# /opt/conda/envs/pennylane/lib/python3.9/site-packages/pennylane/tape/qscript.py in wrapper(*args, **kwargs)
#    1344     def wrapper(*args, **kwargs):
#    1345         with AnnotatedQueue() as q:
# -> 1346             result = fn(*args, **kwargs)
#    1347
#    1348         qscript = QuantumScript.from_queue(q)
#
# /tmp/ipykernel_52/1271582817.py in initial(params)
#       6     for i in range(q):
#       7 #        qml.PauliX(i)
# ----> 8         qml.RX(params[i], wires = i)
#       9     return qml.state()
#      10 params = []
#
# TypeError: 'int' object is not subscriptable

# %%
q = 3
#dev = qml.device("default.qubit", wires=q)
#@qml.qnode(dev)

def initial(q):
    for i in range(q):
        qml.PauliX(i)
#    return qml.state()

#draw2 = qml.draw(initial)   
#print(draw2(q))

# %%
#q = 3
#dev = qml.device("default.qubit", wires=q)
#@qml.qnode(dev)
def ansatz(params):
    for j in range(q):
        qml.RZ(params[j], wires=j)
#    return qml.state()
        
params = [0.1, 0.2, 0.3]
        
draw3 = qml.draw(ansatz)   
print(draw3(params))
# Out:
# 0: ──RZ(0.10)─┤  State
# 1: ──RZ(0.20)─┤  State
# 2: ──RZ(0.30)─┤  State

# %%
dev = qml.device("default.qubit", wires=q)
@qml.qnode(dev)
def Alg(q):
    initial(q)
    ansatz(params)
    return [qml.expval(qml.PauliZ(i)) for i in range (q)]

#params = [0.5, 2.3]
draw1 = qml.draw(Alg)
print(draw1(q))
# Out:
# 0: ──X──RZ(0.10)─┤  <Z>
# 1: ──X──RZ(0.20)─┤  <Z>
# 2: ──X──RZ(0.30)─┤  <Z>

# %%
draw1 = qml.draw(circuit)

# %%
print(draw1(params))
# Out:
# 0: ──Y─╭●─┤
# 1: ──X─╰X─┤  <Z>
# 2: ──Z────┤

# %%
# Out:
# 0: ──X─┤  State
# 1: ──X─┤  State
# 2: ──X─┤  State

# %%
qml.draw(initial)
# Out:
# <function __main__.initial(q)>

# %%
q = 10
dev = qml.device("default.qubit", wires=q)

@qml.qnode(dev)
def initial(params):
    for i in range(q):
#        qml.PauliX(i)
        qml.RX(params[i], wires = i)
    return qml.state()
params = []
for i in range(q):
    params.append(1/random.randint(1,10))

draw2 = qml.draw(initial)   
print(draw2(params))
# Out:
# 0: ──RX(0.17)─┤  State
# 1: ──RX(0.11)─┤  State
# 2: ──RX(0.11)─┤  State
# 3: ──RX(0.50)─┤  State
# 4: ──RX(0.10)─┤  State
# 5: ──RX(0.14)─┤  State
# 6: ──RX(0.14)─┤  State
# 7: ──RX(0.11)─┤  State
# 8: ──RX(0.10)─┤  State
# 9: ──RX(0.17)─┤  State

# %%
random.randint(1,10)
# Out:
# 0
